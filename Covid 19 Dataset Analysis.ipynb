# %% [markdown]
# # Working on Real Project with Python Pandas on 'Covid 19' Dataset

# %% [markdown]
# #                 ........( Covid 19 Data Analysis )........

# %% [markdown]
# #

# %% [markdown]
# #Prepared By Ankur Dey

# %% [markdown]
# #  #*Covid 19 Small Dataset*

# %% [markdown]
# #

# %% [markdown]
# I have taken a small dataset of covid 19 just for understanding purpose. We have to work on original datset which contains 19000 rows.

# %% [markdown]
# The data used here is till 29-April-2021 & has record as on 29-April-2021.

# %% [markdown]
# The data available as a csv file, downloaded from Kaggle.

# %% [markdown]
# I will analyze this dataset using Pandas Dataframe.

# %% [markdown]
# Here, random sets of questions and instructions are given as an example for the practice & learning purpose.

# %% [markdown]
# #

# %%
import pandas as pd

# %%
Covid_data=pd.read_csv('Covid_data.csv')

# %%
Covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
#1
#df.count()
#df.isnull().sum()

# %%
Covid_data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
Covid_data.isnull().sum()

#It detects the missing values from the dataframe.
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %% [markdown]
# #

# %% [markdown]
# #  1. Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %% [markdown]
# #

# %%
#df.groupby('Region').sum().head(50)
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)

# %%
Covid_data.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
Covid_data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered
# Region
# Afghanistan               1939      60        252
# Albania                    766      30        455
# Algeria                   3848     444       1702
# Andorra                    743      42        423
# Angola                      27       2          7
# Antigua and Barbuda         24       3         11
# Argentina                 4285     214       1192
# Armenia                   1932      30        900
# Australia                 6752      91       5715
# Austria                  15402     580      12779
# Azerbaijan                1766      23       1267
# Bahamas                     80      11         23
# Bahrain                   2921       8       1455
# Bangladesh                7103     163        150
# Barbados                    80       7         39
# Belarus                  13181      84       2072
# Belgium                  47859    7501      11283
# Belize                      18       2          9
# ...

# %%
Covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # 2. Remove all the records where the Confirmed Cases are Less Than 10.

# %% [markdown]
# #

# %%
#df.Confirmed<10
#df[df.Confirmed<10]
#df[~(df.Confirmed<10)]
#df=df[~(df.Confirmed<10)]

# %%
Covid_data= Covid_data[~(Covid_data.Confirmed<10)]    #To remove the records satisfying a particular condition

# %%
Covid_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# #

# %% [markdown]
# # 3. In which Region, maximum number of Confirmed cases were recorded ?

# %% [markdown]
# #

# %%
#df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)

# %%
Covid_data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166536
# UK                 166432
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82861
# Brazil              79685
# Canada              52860
# Belgium             47859
# Netherlands         38993
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # 4. In which Region, minimum number of Deaths cases were recorded ?

# %% [markdown]
# #

# %%
#df.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(50)

# %%
Covid_data.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Seychelles                          0
# Saint Lucia                         0
# Central African Republic            0
# Saint Kitts and Nevis               0
# South Sudan                         0
# Rwanda                              0
# Grenada                             0
# Macau                               0
# Madagascar                          0
# Nepal                               0
# Namibia                             0
# Saint Vincent and the Grenadines    0
# Mozambique                          0
# Holy See                            0
# Timor-Leste                         0
# Mongolia                            0
# Uganda                              0
# Laos                                0
# Eritrea                             0
# Vietnam                             0
# Fiji                                0
# Dominica                            0
# Gambia                              1
# ...

# %% [markdown]
# #

# %% [markdown]
# # 5. Visualization Of Data

# %% [markdown]
# #

# %%
df=Covid_data.head(10)

# %%
# Here, I have taken top 10 Regions for better visualization

# %%
df
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6  4/29/2020   NaN            Argentina       4285     214       1192
# 7  4/29/2020   NaN              Armenia       1932      30        900
# 8  4/29/2020   NaN              Austria      15402     580      12779
# 9  4/29/2020   NaN           Azerbaijan       1766      23       1267

# %% [markdown]
# # Piechart Of Deaths Cases in Different Region

# %% [markdown]
# #

# %%
df. groupby(['Region']). sum(). plot(kind='pie', y='Deaths')
# Out:
# <AxesSubplot:ylabel='Deaths'>

# %% [markdown]
# #

# %% [markdown]
# # Bar Chart of Recovered Cases in Different Regions

# %% [markdown]
# #

# %%
 df.plot(x='Region',y='Recovered',kind='bar')
# Out:
# <AxesSubplot:xlabel='Region'>

# %% [markdown]
# #

# %%
df2=Covid_data.head(6)

# %%
# Here, I have taken top 6 Regions for better visualization

# %% [markdown]
# #

# %%
df2
# Out:
#         Date State               Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN          Afghanistan       1939      60        252
# 1  4/29/2020   NaN              Albania        766      30        455
# 2  4/29/2020   NaN              Algeria       3848     444       1702
# 3  4/29/2020   NaN              Andorra        743      42        423
# 4  4/29/2020   NaN               Angola         27       2          7
# 5  4/29/2020   NaN  Antigua and Barbuda         24       3         11

# %% [markdown]
# #

# %% [markdown]
# # Scatter Chart Of Confirmed Cases in different Region

# %% [markdown]
# #

# %%
df2.plot(x='Region',y='Confirmed',kind='scatter')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Confirmed'>

# %% [markdown]
# #

# %% [markdown]
# #  6. How many Confirmed, Deaths & Recovered cases were reported from India & US till 29 April 2020 ?

# %% [markdown]
# #

# %%
#df[df.region=='Country_name']

# %%
Covid_data[Covid_data.Region=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# #

# %% [markdown]
# # #For USA

# %% [markdown]
# #

# %%
Covid_data[Covid_data.Region=='US']
# Out:
#           Date                         State Region  Confirmed  Deaths  \
# 181  4/29/2020                       Alabama     US       6912     256
# 182  4/29/2020                        Alaska     US        355       9
# 186  4/29/2020                       Arizona     US       7209     308
# 187  4/29/2020                      Arkansas     US       3193      57
# 195  4/29/2020                    California     US      48747    1946
# 199  4/29/2020                      Colorado     US      14758     766
# 200  4/29/2020                   Connecticut     US      26767    2169
# 202  4/29/2020                      Delaware     US       4655     144
# 204  4/29/2020  Diamond Princess cruise ship     US         49       0
# 205  4/29/2020          District of Columbia     US       4106     205
# 208  4/29/2020                       Florida     US      33193    1218
# 213  4/29/2020                       Georgia     US      25775    1101
# ...

# %% [markdown]
# #

# %% [markdown]
# # 7a. Sort the entire data wrt No. of Confirmed cases in Ascending order.

# %% [markdown]
# # 7b. Sort the entire data wrt No. of Confirmed cases in Descending order.

# %% [markdown]
# #

# %%
#df.sort_values(by=['Confirmed'], ascending= True)

# %%
Covid_data.sort_values(by=['Confirmed'], ascending= True).head(50)
# Out:
#           Date                         State  \
# 156  4/29/2020                           NaN
# 70   4/29/2020                           NaN
# 59   4/29/2020                           NaN
# 318  4/29/2020                         Yukon
# 217  4/29/2020                     Greenland
# 256  4/29/2020                    Montserrat
# 144  4/29/2020                           NaN
# 27   4/29/2020                           NaN
# 306  4/29/2020      Turks and Caicos Islands
# 118  4/29/2020                           NaN
# 215  4/29/2020                Grand Princess
# 206  4/29/2020   Falkland Islands (Malvinas)
# 270  4/29/2020      Northern Mariana Islands
# 136  4/29/2020                           NaN
# 138  4/29/2020                           NaN
# 45   4/29/2020                           NaN
# 201  4/29/2020                       Curacao
# 114  4/29/2020                           NaN
# 137  4/29/2020                           NaN
# 260  4/29/2020                 New Caledonia
# ...

# %%
#df.sort_values(by=['Confirmed'], ascending= False)

# %%
Covid_data.sort_values(by=['Confirmed'], ascending= False).head(50)
# Out:
#           Date          State          Region  Confirmed  Deaths  Recovered
# 265  4/29/2020       New York              US     299691   23477          0
# 153  4/29/2020            NaN           Spain     236899   24275     132929
# 80   4/29/2020            NaN           Italy     203591   27682      71252
# 168  4/29/2020            NaN              UK     165221   26097          0
# 57   4/29/2020            NaN          France     165093   24087      48228
# 61   4/29/2020            NaN         Germany     161539    6467     120400
# 167  4/29/2020            NaN          Turkey     117589    3081      44040
# 262  4/29/2020     New Jersey              US     116365    6771          0
# 134  4/29/2020            NaN          Russia      99399     972      10286
# 76   4/29/2020            NaN            Iran      93657    5957      73791
# 22   4/29/2020            NaN          Brazil      79685    5513      34132
# ...

# %% [markdown]
# #

# %% [markdown]
# # 7c. Sort the entire data wrt No. of Recovered cases in Descending order.

# %% [markdown]
# #

# %%
#df.sort_values(by=['Recovered'], ascending= False)

# %%
Covid_data.sort_values(by=['Recovered'], ascending= False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 78   4/29/2020              NaN               Ireland      20253    1190
# 8    4/29/2020              NaN               Austria      15402     580
# 107  4/29/2020              NaN                Mexico      17799    1732
# ...
